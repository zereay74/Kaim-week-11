# %%
import os
import sys
sys.path.append(os.path.abspath('..')) # add parent path to working directory

# %%
from importlib import reload
from scripts import stock_price_forcasting
reload(stock_price_forcasting)
# Out:
# <module 'scripts.stock_price_forcasting' from 'c:\\ML and DS Files\\Kifiya AI\\Kaim-week-11\\scripts\\stock_price_forcasting.py'>

# %%
from scripts.stock_price_forcasting import StockPriceForecaster

# %%
# instantiate the stockprice class and load data
forecaster = StockPriceForecaster('../week 11 data/Data/TSLA.csv')
# Out:
# 2025-03-02 12:10:18,426 - INFO - Data loaded successfully.
# 2025-03-02 12:10:18,428 - INFO - Data split into training (2028) and testing (507).

# %%
# Train ARIMA
forecaster.train_arima()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12684.802, Time=1.51 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12680.726, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12679.653, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12679.753, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12678.997, Time=0.21 sec
# 2025-03-02 12:10:22,287 - INFO - Optimal ARIMA order: (0, 1, 0)
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=12680.805, Time=1.36 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 3.821 seconds

# %%
# Train SARIMA
forecaster.train_sarima()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=12678.187, Time=4.31 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=12680.726, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=12680.415, Time=0.91 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=12680.778, Time=1.02 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=12678.997, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=12685.575, Time=3.90 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=12685.255, Time=5.38 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=12655.358, Time=19.27 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=12653.424, Time=10.31 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=12651.430, Time=7.76 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=12683.246, Time=2.74 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=12653.412, Time=10.09 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=12676.166, Time=4.25 sec
# ...

# %%
forecaster.train_lstm()
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - loss: 0.0235
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0025
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0027
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0025
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0020
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0020
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0018
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0019
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0020
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0014
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0014
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0014
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0012
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0013
# Epoch 15/50
# ...

# %%
forecaster.evaluate_arima()
# Out:
# 2025-03-02 12:15:15,405 - INFO - ARIMA - MAE: 32.8242, RMSE: 37.7478, MAPE: nan%

# %%
forecaster.evaluate_sarima()
# Out:
# 2025-03-02 12:15:15,430 - INFO - SARIMA - MAE: 37.0361, RMSE: 42.1224, MAPE: nan%

# %%
forecaster.evaluate_lstm()
# Out:
# 2025-03-02 12:15:15,452 - INFO - LSTM - MAE: 41.4584, RMSE: 45.5200, MAPE: 22.55%

# %%
forecaster.plot_forecasts()

# %%
tesla_predicted_dataframe = forecaster.get_lstm_forecast_df("../week 11 data/Data/Predicted Data/LSTM_Tesla_Forecast.csv")
# Out:
# 2025-03-02 12:15:16,051 - INFO - LSTM forecast saved as ../week 11 data/Data/Predicted Data/LSTM_Tesla_Forecast.csv

# %% [markdown]
# # BND

# %%
forecaster = StockPriceForecaster("../week 11 data/Data/BND.csv")
forecaster.train_arima()
forecaster.train_sarima()
forecaster.train_lstm()
forecaster.evaluate_arima()
forecaster.evaluate_sarima()
forecaster.evaluate_lstm()
forecaster.plot_forecasts()
forecaster.get_lstm_forecast_df('../week 11 data/Data/Predicted Data/LSTM_BND_Forecast.csv')
# Out:
# 2025-03-02 12:46:55,692 - INFO - Data loaded successfully.
# 2025-03-02 12:46:55,694 - INFO - Data split into training (2028) and testing (507).
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-228.141, Time=1.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-178.561, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-176.835, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-176.919, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-180.201, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-199.616, Time=2.33 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-203.431, Time=1.22 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-226.146, Time=2.38 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-226.146, Time=2.88 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-179.415, Time=0.92 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-202.890, Time=1.65 sec
# ...

# %% [markdown]
# # SPY

# %%
forecaster = StockPriceForecaster("../week 11 data/Data/SPY.csv")
forecaster.train_arima()
forecaster.train_sarima()
forecaster.train_lstm()
forecaster.evaluate_arima()
forecaster.evaluate_sarima()
forecaster.evaluate_lstm()
forecaster.plot_forecasts()
forecaster.get_lstm_forecast_df('../week 11 data/Data/Predicted Data/LSTM_SPY_Forecast.csv')
# Out:
# 2025-03-02 12:57:15,216 - INFO - Data loaded successfully.
# 2025-03-02 12:57:15,217 - INFO - Data split into training (2028) and testing (507).
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=10657.809, Time=1.60 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=10743.274, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=10727.392, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=10728.794, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=10743.258, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=10727.900, Time=1.08 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=10728.170, Time=0.79 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=10659.136, Time=1.65 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=10728.918, Time=2.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=10727.003, Time=0.72 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=10727.570, Time=1.19 sec
# ...
